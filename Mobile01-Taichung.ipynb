# %%
import requests
from bs4 import BeautifulSoup
import time

with open('mobile01-Taichung.txt', 'r', encoding='UTF-8') as f:
    info = f.read()
info.split('\n')
# Out:
# ['https://www.mobile01.com/waypointtopicdetail.php?f=195&t=5224093',
#  '(食)台中 茶六燒肉堂 輕井澤系列x好吃推薦',
#  '2017-07-30 18:48',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=195&t=5232991',
#  '台中 菜頭粿爺爺 有人吃過南瓜口味嗎?',
#  '2017-08-09 11:08',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=195&t=5199275',
#  '情侶台中旅行景點推薦',
#  '2017-07-03 23:22',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=195&t=5219971',
#  '【分享】台中在地人才知道的路邊攤滷肉飯「康 京兆堂」肉角飯',
#  '2017-07-26 04:16',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=195&t=5229657',
#  '南屯蕭中清店是不是歇業了啊？',
#  '2017-08-05 16:17',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=195&t=1142022',
#  '請推薦台中市特有的伴手禮..',
#  '2009-07-15 18:50',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=195&t=5218819',
#  '台中夜景',
#  '2017-07-24 22:52',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=195&t=5202668',
#  '【分享】台中舊市區最強老店之一「烤肉沙拉店」',
#  '2017-07-07 03:33',
# ...

# %%
info.split('\n')[0]
# Out:
# 'https://www.mobile01.com/waypointtopicdetail.php?f=195&t=5224093'

# %%
for i in range(0,len(info.split('\n'))+1):
    if i%3 == 0:
        res = requests.get(info.split('\n')[i])
        #soup = BeautifulSoup(res.text, 'lxml')
        with open('D:\Project_Image\mobile01\台中\{}.html'.format(i//3+1), 'w', encoding='UTF-8') as f:            
            f.write(res.text)
            f.close()
            time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-3-5999362d8e24> in <module>()
#       1 for i in range(0,len(info.split('\n'))+1):
#       2     if i%3 == 0:
# ----> 3         res = requests.get(info.split('\n')[i])
#       4         #soup = BeautifulSoup(res.text, 'lxml')
#       5         with open('D:\Project_Image\mobile01\台中\{}.html'.format(i//3+1), 'w', encoding='UTF-8') as f:
#
# C:\Users\Java\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\Users\Java\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ...
