# %%
import requests
from bs4 import BeautifulSoup
import time

with open('mobile01-newTaipei.txt', 'r', encoding='UTF-8') as f:
    info = f.read()
info.split('\n')
#info[2]
# Out:
# ['\ufeffhttps://www.mobile01.com/waypointtopicdetail.php?f=190&t=5218771',
#  '臺灣極東點 -- 新北市 貢寮區 三貂角燈塔',
#  '2017-07-24 21:54',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=190&t=5232305',
#  '東北角的交通問題',
#  '2017-08-08 16:59',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=190&t=5230676',
#  '不愉快的旅遊之新竹老爺酒店',
#  '2017-08-06 23:41',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=190&t=5229069',
#  '由福隆前往淡水漁人碼頭開車路程選擇',
#  '2017-08-04 18:26',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=190&t=5215294',
#  '新北適合帶小孩去的好地方?',
#  '2017-07-20 22:28',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=190&t=5217719',
#  '【三重】好吃不踩雷的早午餐，美味超滿足',
#  '2017-07-23 20:35',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=190&t=5228050',
#  '【永和美食】『阿鵬師老麵包子饅頭專賣店』純手工/老麵發酵/養生.健康/天然食材/扎實口感/...',
#  '2017-08-03 15:24',
#  'https://www.mobile01.com/waypointtopicdetail.php?f=190&t=5228276',
#  '新北藍色公路台北淡水一日遊推薦│江翠礫間蝴蝶水岸公園 華江濕地單車遊 水上巴士 華江馬頭 ...',
# ...

# %%
info.split('\n')[12633]
# Out:
# 'https://www.mobile01.com/waypointtopicdetail.php?f=190&t=1129288'

# %%
import requests
from bs4 import BeautifulSoup
import time

res = requests.get("https://www.mobile01.com/waypointtopicdetail.php?f=190&t=5218771")
        #soup = BeautifulSoup(res.text, 'lxml')
with open('D:\Project_Image\mobile01\新北\ 1.html', 'w', encoding='UTF-8') as f:            
    f.write(res.text)
    f.close()
    time.sleep(3)

# %%
for i in range(12633,len(info.split('\n'))+1):
    if i%3 == 0:
        res = requests.get(info.split('\n')[i])
        #soup = BeautifulSoup(res.text, 'lxml')
        with open('D:\Project_Image\mobile01\新北\{}.html'.format(i//3+1), 'w', encoding='UTF-8') as f:            
            f.write(res.text)
            f.close()
            time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-8-19e652010371> in <module>()
#       1 for i in range(12633,len(info.split('\n'))+1):
#       2     if i%3 == 0:
# ----> 3         res = requests.get(info.split('\n')[i])
#       4         #soup = BeautifulSoup(res.text, 'lxml')
#       5         with open('D:\Project_Image\mobile01\新北\{}.html'.format(i//3+1), 'w', encoding='UTF-8') as f:
#
# C:\Users\Java\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\Users\Java\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ...

# %%
len(info.split('\n'))
# Out:
# 32176

# %%
info.split('\n')[0]
# Out:
# 'https://www.mobile01.com/waypointtopicdetail.php?f=189&t=5224018'

# %%
4//3
# Out:
# 1
